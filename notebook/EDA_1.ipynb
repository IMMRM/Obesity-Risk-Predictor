# %% [markdown]
# # Exploratory Data Analysis

# %%
## importing standard libraries
import pandas as pd
import numpy as np 
import warnings
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))
import config as cfg 
import sweetviz as sv 
warnings.filterwarnings("ignore")

# %%
#let's define a feature description function

lst = [
    ("Gender", "Sex"),
    ("Age", "Age"),
    ("Height", "Height"),
    ("Weight", "Weight"),
    ("FHWO", "Overweight family members"),
    ("FAVC", "Consume high-calorie foods frequently"),
    ("FCVC", "Number of meals where you usually eat vegetables"),
    ("NCP", "Number of main meals a day"),
    ("CAEC", "Eat food between meals"),
    ("SMOKE", "How often you smoke"),
    ("CH2O", "Liters of water you drink a day"),
    ("SCC", "Monitor the calories you consume daily"),
    ("FAF", "Frequency of days per week that you often have physical activity"),
    ("TUE", "Time of use of technological devices on a daily basis"),
    ("CALC", "Frequency of alcohol intake"),
    ("MTRANS", "Means of transportation that you use regularly"),
    ("NObeyesdad", "Body mass index")
]
feature_description=dict(lst)

# %%
#Let's import the data
raw_df=pd.read_csv(cfg.raw_train_data)
raw_df.head(10)
# Out:
#    id  Gender        Age    Height      Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998   81.669950                            yes
# 1   1  Female  18.000000  1.560000   57.000000                            yes
# 2   2  Female  18.000000  1.711460   50.165754                            yes
# 3   3  Female  20.952737  1.710730  131.274851                            yes
# 4   4    Male  31.641081  1.914186   93.798055                            yes
# 5   5    Male  18.128249  1.748524   51.552595                            yes
# 6   6    Male  29.883021  1.754711  112.725005                            yes
# 7   7    Male  29.891473  1.750150  118.206565                            yes
# 8   8    Male  17.000000  1.700000   70.000000                             no
# 9   9  Female  26.000000  1.638836  111.275646                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O  SCC       FAF  \
# ...

# %%
print(feature_description["FCVC"])
print(feature_description["FAVC"])
print(feature_description["NCP"])
print(feature_description["CAEC"])
print(feature_description["CH2O"])
print(feature_description["FAF"])
print(feature_description["CALC"])
print(feature_description["TUE"])
print(feature_description["MTRANS"])
# Out:
# Number of meals where you usually eat vegetables
# Consume high-calorie foods frequently
# Number of main meals a day
# Eat food between meals
# Liters of water you drink a day
# Frequency of days per week that you often have physical activity
# Frequency of alcohol intake
# Time of use of technological devices on a daily basis
# Means of transportation that you use regularly

# %%
#let's look at the shape
raw_df.shape
# Out:
# (20758, 18)

# %%
#Let's generate EDA report
report=sv.analyze(raw_df)
report.show_html("Obesity_dataset_report.html",open_browser=True)
# Out:
# [Summarizing dataframe]                      |          | [  0%]   00:00 -> (? left)
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:03 -> (00:00 left)
# Report Obesity_dataset_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ### Conclusions from the report:
#
# * There are total `207588` records in our train dataset
# * There's no missing values
# * There are no duplicates
# * We have an almost balanced dataset
